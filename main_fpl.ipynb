# %%
for_the_players_ids = "https://fantasy.premierleague.com/api/bootstrap-static/"

# %%
detailed_performance_of_players = "https://fantasy.premierleague.com/api/element-summary/111/"
# where 111 is the id of the element (player) in the static bootstrap.

# %%
from fpl import FPL
import aiohttp
import asyncio
async def main():
    async with aiohttp.ClientSession() as session:
        fpl = FPL(session)
        gameweek = await fpl.get_gameweek(3)
    print(gameweek,': ', dir(gameweek), gameweek.highest_scoring_entry)
# Python 3.7+
await main()
#nest_asyncio.run(main())
#asyncio.run(main())

# %%
# manager:
https://fantasy.premierleague.com/api/entry/414154/
# picks:
https://fantasy.premierleague.com/api/entry/4791912/event/8/picks/

# %%
from fpl import FPL
import aiohttp
import asyncio
import time

# get the start time
st = time.time()

top_gw_managers = []
async def main():
    async with aiohttp.ClientSession() as session:
        fpl = FPL(session)
        for i in range(80000,90000):
            user = await fpl.get_user(i+1)
            if user.summary_event_points >= 100:
                print(user.id)
                top_gw_managers.append(user.id)

await main()

et = time.time()

# get the execution time
elapsed_time = et - st
print('Execution time:', elapsed_time, 'seconds')
# Out:
# 80268
# 80410
# 80790
# 81061
# 81421
# 81537
# 81560
# 81848
# 82042
# 82180
# 82359
# 82531
# 82754
# 83445
# 83520
# 83891
# 83919
# 84016
# 84569
# 84931
# 85041
# 85357
# 85595
# 85726
# 86154
# 86241
# 86602
# 86640
# 86643
# 86756
# 87166
# 87272
# 87360
# 87549
# 87677
# 87741
# 87937
# 89025
# 89372
# 89391
# 89489
# Execution time: 717.1040124893188 seconds

# %%
import requests
import pandas as pd
import json
import pprint
my_tops = []

#base_url_draft = "https://draft.premierleague.com/api/bootstrap-static"
base_url_fantasy = "https://fantasy.premierleague.com/api/bootstrap-static/"

base_response = requests.get(base_url_fantasy)
base_data = json.loads(base_response.text)
for player in base_data['elements']:
    if player["web_name"] == "Son":
        print(player["id"])
#pprint.pprint(base_data['elements'])
# Out:
# 428

# %%
import requests
import pandas as pd
import json
import pprint
my_tops = []

base_url_draft = "https://draft.premierleague.com/api/bootstrap-static"
base_url_fantasy = "https://fantasy.premierleague.com/api/bootstrap-static"

base_response = requests.get(base_url_draft)
base_data = json.loads(base_response.text)
#pprint.pprint(base_data["elements"][45]['id'])

all_managers_dic = {
                    263589: 'Germany 🇩🇪',
                    236729: 'United States 🇺🇲',
                    243671: 'South Korea🇰🇷',
                    236062: 'Great Britain 🇬🇧',
                    236257: 'France 🇫🇷',
                    236216: 'The Soviet Union ☭',
                    243654: 'Australia 🇦🇺',
                    253790: 'Hungary 🇭🇺',
                    236145: 'New Zealand 🇳🇿',
                    236453: 'Italy 🇮🇹',
                    236143: 'Argentina 🇦🇷',
                    263294: 'Netherlands 🇳🇱',
                    236479: 'Japan 🇯🇵',
                    237205: 'China 🇨🇳',
                    236057: 'Canada 🇨🇦',
                    235910: '🏁Referee 6🏁'
                    }

managers_points = {}
for manager, manager_name in all_managers_dic.items():
    url = f"https://draft.premierleague.com/api/entry/{manager}/event/5"
    response = requests.get(url)
    data = json.loads(response.text)
    #pprint.pprint(data)
    players = {}
    for player in data["picks"]:
        for index, a_player in enumerate(base_data["elements"]):
            if player['element'] == a_player['id']:
                my_player_info = {}
                player_name = base_data["elements"][index]['web_name']
                event_points = base_data["elements"][index]['event_points']
                element_type = base_data["elements"][index]['element_type']
                # player['element'] is exactly the id in the bootsrap static and detailed pages
                player_details_url = f"https://fantasy.premierleague.com/api/element-summary/{player['element']}/"
                player_details_response = requests.get(player_details_url)
                player_details = json.loads(player_details_response.text)
                if player['element'] == 428:
                    pprint.pprint(player_details["history"][4])
                minutes = player_details["history"][-1]["minutes"]

                
                my_player_info = {
                    "event_points": event_points,
                    "element_type": element_type,
                    "minutes": minutes,
                }
                players[player_name] = my_player_info
                break
    managers_points[manager_name] = players
pprint.pprint(managers_points)
#     my_rank = data["current"][3]['rank']
#     if not my_rank:
#         continue
#     if my_rank <= 3000:
#         my_tops.append(manager)
#     if manager%1000 == 0:
#         print("1k plus.")
    #print(data["current"][3]['rank'])
#pprint.pprint(data)
# Out:
# {'assists': 0,
#  'bonus': 0,
#  'bps': 2,
#  'clean_sheets': 0,
#  'creativity': '1.8',
#  'element': 428,
#  'fixture': 47,
#  'goals_conceded': 1,
#  'goals_scored': 0,
#  'ict_index': '4.0',
#  'influence': '0.6',
#  'kickoff_time': '2022-08-31T18:45:00Z',
#  'minutes': 90,
#  'opponent_team': 19,
#  'own_goals': 0,
#  'penalties_missed': 0,
#  'penalties_saved': 0,
#  'red_cards': 0,
#  'round': 5,
#  'saves': 0,
#  'selected': 1156313,
#  'team_a_score': 1,
#  'team_h_score': 1,
#  'threat': '38.0',
#  'total_points': 2,
#  'transfers_balance': -317771,
#  'transfers_in': 19806,
#  'transfers_out': 337577,
#  'value': 118,
#  'was_home': False,
#  'yellow_cards': 0}
# {'Argentina 🇦🇷': {'Ayew': {'element_type': 3, 'event_points': 0, 'minutes': 90},
#                   'Aït-Nouri': {'element_type': 2,
#                                 'event_points': 0,
#                                 'minutes': 90},
#                   'Darlow': {'element_type': 1,
# ...

# %%
import requests
import pandas as pd
import json
import pprint
my_tops = []

base_url = "https://draft.premierleague.com/api/bootstrap-static"
base_response = requests.get(base_url)
base_data = json.loads(base_response.text)
pprint.pprint(base_data["elements"][45]['id'])
for league_id in [263589,]:
    url = f"https://draft.premierleague.com/api/draft/{league_id}/"
    response = requests.get(url)
    data = json.loads(response.text)
    pprint.pprint(data)
# Out:
# 46
# {'detail': 'Authentication credentials were not provided.'}

# %%
my_string = """
<div class="Layout__Main-wu95f7-1 kuyNCc"><h2 class="sectionTitle ism-section-title">برلین (Group 6)</h2><div class="table"><table class="ism-table"><thead class="ism-thead-bold"><tr><th>Rank</th><th>Team &amp; Manager</th><th>GW</th><th>TOT</th></tr></thead><tbody><tr class="ism-table__highlight"><td>1 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="up" class="Movement__MovementIcon-t97k3u-0 kzRnni"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/263589/event/5"><strong>Germany 🇩🇪</strong><br>Majid </a></td><td>55</td><td>232</td></tr><tr><td>2 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236729/event/5"><strong>United States 🇺🇲</strong><br>Parsa </a></td><td>31</td><td>229</td></tr><tr><td>3 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/243671/event/5"><strong>🇰🇷South Korea🇰🇷</strong><br>Porya </a></td><td>20</td><td>209</td></tr><tr><td>4 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="same" class="Movement__MovementIcon-t97k3u-0 fSBpnr"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236062/event/5"><strong>Great Britain 🇬🇧</strong><br>Seyyed MohammadHossein </a></td><td>36</td><td>196</td></tr><tr><td>5 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="up" class="Movement__MovementIcon-t97k3u-0 kzRnni"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236257/event/5"><strong>France 🇫🇷</strong><br>saeed </a></td><td>45</td><td>194</td></tr><tr><td>6 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236216/event/5"><strong>The Soviet Union ☭</strong><br>Hadi </a></td><td>36</td><td>192</td></tr><tr><td>7 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="up" class="Movement__MovementIcon-t97k3u-0 kzRnni"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/243654/event/5"><strong>Australia 🇦🇺</strong><br>Alimohammad </a></td><td>52</td><td>191</td></tr><tr><td>8 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/253790/event/5"><strong>🇭🇺Hungary 🇭🇺</strong><br>ALI </a></td><td>35</td><td>185</td></tr><tr><td>9 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="same" class="Movement__MovementIcon-t97k3u-0 fSBpnr"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236145/event/5"><strong>New Zealand 🇳🇿</strong><br>mehdi </a></td><td>39</td><td>182</td></tr><tr><td>10 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="same" class="Movement__MovementIcon-t97k3u-0 fSBpnr"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236453/event/5"><strong>Italy 🇮🇹</strong><br>Erfan </a></td><td>39</td><td>181</td></tr><tr><td>11 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236143/event/5"><strong>Argentina 🇦🇷</strong><br>Muhammad </a></td><td>25</td><td>176</td></tr><tr><td>12 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/263294/event/5"><strong>🇳🇱Netherlands 🇳🇱</strong><br>Yosef </a></td><td>27</td><td>167</td></tr><tr><td>13 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="up" class="Movement__MovementIcon-t97k3u-0 kzRnni"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236479/event/5"><strong>Japan 🇯🇵</strong><br>Seyed Mohammad </a></td><td>30</td><td>148</td></tr><tr><td>14 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/237205/event/5"><strong>China 🇨🇳</strong><br>imey </a></td><td>18</td><td>141</td></tr><tr><td>15 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="same" class="Movement__MovementIcon-t97k3u-0 fSBpnr"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236057/event/5"><strong>Canada 🇨🇦</strong><br>Nima </a></td><td>19</td><td>127</td></tr><tr><td>16 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="same" class="Movement__MovementIcon-t97k3u-0 fSBpnr"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/235910/event/5"><strong>🏁Referee 6🏁</strong><br>Mahyar </a></td><td>0</td><td>9</td></tr></tbody></table></div></div>
"""
splitted = my_string.split('href="/entry/')

# %%
len(splitted)
# Out:
# 17

# %%
list_of_team_ids = []
for i in range(1, 17):
    list_of_team_ids.append(int(splitted[i].split("/")[0]))

# %%
list_of_team_ids
# Out:
# [263589,
#  236729,
#  243671,
#  236062,
#  236257,
#  236216,
#  243654,
#  253790,
#  236145,
#  236453,
#  236143,
#  263294,
#  236479,
#  237205,
#  236057,
#  235910]

# %%
my_string = """
<div class="Layout__Main-wu95f7-1 kuyNCc"><h2 class="sectionTitle ism-section-title">برلین (Group 6)</h2><div class="table"><table class="ism-table"><thead class="ism-thead-bold"><tr><th>Rank</th><th>Team &amp; Manager</th><th>GW</th><th>TOT</th></tr></thead><tbody><tr class="ism-table__highlight"><td>1 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="up" class="Movement__MovementIcon-t97k3u-0 kzRnni"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/263589/event/5"><strong>Germany 🇩🇪</strong><br>Majid </a></td><td>55</td><td>232</td></tr><tr><td>2 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236729/event/5"><strong>United States 🇺🇲</strong><br>Parsa </a></td><td>31</td><td>229</td></tr><tr><td>3 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/243671/event/5"><strong>🇰🇷South Korea🇰🇷</strong><br>Porya </a></td><td>20</td><td>209</td></tr><tr><td>4 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="same" class="Movement__MovementIcon-t97k3u-0 fSBpnr"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236062/event/5"><strong>Great Britain 🇬🇧</strong><br>Seyyed MohammadHossein </a></td><td>36</td><td>196</td></tr><tr><td>5 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="up" class="Movement__MovementIcon-t97k3u-0 kzRnni"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236257/event/5"><strong>France 🇫🇷</strong><br>saeed </a></td><td>45</td><td>194</td></tr><tr><td>6 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236216/event/5"><strong>The Soviet Union ☭</strong><br>Hadi </a></td><td>36</td><td>192</td></tr><tr><td>7 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="up" class="Movement__MovementIcon-t97k3u-0 kzRnni"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/243654/event/5"><strong>Australia 🇦🇺</strong><br>Alimohammad </a></td><td>52</td><td>191</td></tr><tr><td>8 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/253790/event/5"><strong>🇭🇺Hungary 🇭🇺</strong><br>ALI </a></td><td>35</td><td>185</td></tr><tr><td>9 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="same" class="Movement__MovementIcon-t97k3u-0 fSBpnr"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236145/event/5"><strong>New Zealand 🇳🇿</strong><br>mehdi </a></td><td>39</td><td>182</td></tr><tr><td>10 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="same" class="Movement__MovementIcon-t97k3u-0 fSBpnr"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236453/event/5"><strong>Italy 🇮🇹</strong><br>Erfan </a></td><td>39</td><td>181</td></tr><tr><td>11 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236143/event/5"><strong>Argentina 🇦🇷</strong><br>Muhammad </a></td><td>25</td><td>176</td></tr><tr><td>12 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/263294/event/5"><strong>🇳🇱Netherlands 🇳🇱</strong><br>Yosef </a></td><td>27</td><td>167</td></tr><tr><td>13 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="up" class="Movement__MovementIcon-t97k3u-0 kzRnni"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236479/event/5"><strong>Japan 🇯🇵</strong><br>Seyed Mohammad </a></td><td>30</td><td>148</td></tr><tr><td>14 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="down" class="Movement__MovementIcon-t97k3u-0 CEEXJ"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/237205/event/5"><strong>China 🇨🇳</strong><br>imey </a></td><td>18</td><td>141</td></tr><tr><td>15 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="same" class="Movement__MovementIcon-t97k3u-0 fSBpnr"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/236057/event/5"><strong>Canada 🇨🇦</strong><br>Nima </a></td><td>19</td><td>127</td></tr><tr><td>16 <svg xmlns="http://www.w3.org/2000/svg" width="16" height="16" viewBox="0 0 16 16" status="same" class="Movement__MovementIcon-t97k3u-0 fSBpnr"><g fill-rule="evenodd"><path d="M8,16 C8.85354691,16 9.67587305,15.866328 10.4471863,15.618776 C13.6684789,14.5849062 16,11.5647311 16,8 C16,3.581722 12.418278,0 8,0 C3.581722,0 0,3.581722 0,8 C0,12.418278 3.581722,16 8,16 Z"></path><path fill="currentColor" fill-rule="nonzero" d="M4.5,6.27851588 L5.1004646,5.63925794 C5.43077928,5.2876031 5.70475818,5 5.70967916,5 C5.71460014,5 6.23194007,5.54639596 6.85921456,6.2144865 L8,7.428973 L9.14078544,6.2144865 C9.76831893,5.5467015 10.2856309,5 10.2903208,5 C10.2952427,5 10.5695007,5.28761055 10.8995354,5.63925794 L11.5,6.27851588 L9.75217699,8.13925794 C8.79080084,9.16274432 8.00246399,10 8.000014,10 C7.99756401,10 7.20894716,9.16281884 6.24785101,8.13925794 L4.5,6.27851588 Z" transform="matrix(1 0 0 -1 0 15)"></path></g></svg></td><td><a href="/entry/235910/event/5"><strong>🏁Referee 6🏁</strong><br>Mahyar </a></td><td>0</td><td>9</td></tr></tbody></table></div></div>
"""
team_name_splitted = my_string.split('event/5"><strong>')

# %%
list_of_team_names = []
for i in range(1, 17):
    list_of_team_names.append(team_name_splitted[i].split("<")[0])

# %%
list_of_team_names
# Out:
# ['Germany 🇩🇪',
#  'United States 🇺🇲',
#  '🇰🇷South Korea🇰🇷',
#  'Great Britain 🇬🇧',
#  'France 🇫🇷',
#  'The Soviet Union ☭',
#  'Australia 🇦🇺',
#  '🇭🇺Hungary 🇭🇺',
#  'New Zealand 🇳🇿',
#  'Italy 🇮🇹',
#  'Argentina 🇦🇷',
#  '🇳🇱Netherlands 🇳🇱',
#  'Japan 🇯🇵',
#  'China 🇨🇳',
#  'Canada 🇨🇦',
#  '🏁Referee 6🏁']

# %%
team_info_dic = dict(zip(list_of_team_ids,list_of_team_names))

# %%
team_info_dic
# Out:
# {263589: 'Germany 🇩🇪',
#  236729: 'United States 🇺🇲',
#  243671: '🇰🇷South Korea🇰🇷',
#  236062: 'Great Britain 🇬🇧',
#  236257: 'France 🇫🇷',
#  236216: 'The Soviet Union ☭',
#  243654: 'Australia 🇦🇺',
#  253790: '🇭🇺Hungary 🇭🇺',
#  236145: 'New Zealand 🇳🇿',
#  236453: 'Italy 🇮🇹',
#  236143: 'Argentina 🇦🇷',
#  263294: '🇳🇱Netherlands 🇳🇱',
#  236479: 'Japan 🇯🇵',
#  237205: 'China 🇨🇳',
#  236057: 'Canada 🇨🇦',
#  235910: '🏁Referee 6🏁'}

# %%
zipped_list_info
# Out:
# [(263589, 'Germany 🇩🇪'),
#  (236729, 'United States 🇺🇲'),
#  (243671, '🇰🇷South Korea🇰🇷'),
#  (236062, 'Great Britain 🇬🇧'),
#  (236257, 'France 🇫🇷'),
#  (236216, 'The Soviet Union ☭'),
#  (243654, 'Australia 🇦🇺'),
#  (253790, '🇭🇺Hungary 🇭🇺'),
#  (236145, 'New Zealand 🇳🇿'),
#  (236453, 'Italy 🇮🇹'),
#  (236143, 'Argentina 🇦🇷'),
#  (263294, '🇳🇱Netherlands 🇳🇱'),
#  (236479, 'Japan 🇯🇵'),
#  (237205, 'China 🇨🇳'),
#  (236057, 'Canada 🇨🇦'),
#  (235910, '🏁Referee 6🏁')]
